# %% [markdown]
# **Rafly Athalla       (1301194216)**
#
# **Zahra Fadiah Putri  (1301194212)**
#
# **IF-43-01**

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import random
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
from sklearn import tree

# %%
df_test = pd.read_csv('kendaraan_test.csv')
df_train = pd.read_csv('kendaraan_train.csv')

# %%
df_test
# Out:
#       Jenis_Kelamin  Umur  SIM  ...  Kanal_Penjualan  Lama_Berlangganan Tertarik
# 0            Wanita    49    1  ...               26                145        0
# 1              Pria    22    1  ...              152                241        0
# 2              Pria    24    1  ...              152                 62        0
# 3              Pria    46    1  ...              124                 34        0
# 4              Pria    35    1  ...              152                229        0
# ...             ...   ...  ...  ...              ...                ...      ...
# 47634          Pria    61    1  ...              124                 67        0
# 47635          Pria    41    1  ...              157                232        0
# 47636          Pria    24    1  ...              152                211        0
# 47637          Pria    59    1  ...               26                239        1
# 47638          Pria    52    1  ...              124                170        0
#
# [47639 rows x 11 columns]

# %%
df_train
# Out:
#             id Jenis_Kelamin  ...  Lama_Berlangganan  Tertarik
# 0            1        Wanita  ...               97.0         0
# 1            2          Pria  ...              158.0         0
# 2            3           NaN  ...              119.0         0
# 3            4        Wanita  ...               63.0         0
# 4            5          Pria  ...              194.0         0
# ...        ...           ...  ...                ...       ...
# 285826  285827        Wanita  ...              217.0         0
# 285827  285828        Wanita  ...               50.0         0
# 285828  285829        Wanita  ...              226.0         0
# 285829  285830          Pria  ...              270.0         0
# 285830  285831          Pria  ...               44.0         0
#
# [285831 rows x 12 columns]

# %% [markdown]
# Eksplorasi data

# %%
# Menggabungkan dataframe testing dan training
dataframe = pd.concat([df_test,df_train]).drop_duplicates().reset_index(drop=True)
dataframe
# Out:
#        Jenis_Kelamin  Umur  SIM  ...  Lama_Berlangganan  Tertarik        id
# 0             Wanita  49.0  1.0  ...              145.0         0       NaN
# 1               Pria  22.0  1.0  ...              241.0         0       NaN
# 2               Pria  24.0  1.0  ...               62.0         0       NaN
# 3               Pria  46.0  1.0  ...               34.0         0       NaN
# 4               Pria  35.0  1.0  ...              229.0         0       NaN
# ...              ...   ...  ...  ...                ...       ...       ...
# 333462        Wanita  23.0  1.0  ...              217.0         0  285827.0
# 333463        Wanita  21.0  1.0  ...               50.0         0  285828.0
# 333464        Wanita  23.0  1.0  ...              226.0         0  285829.0
# 333465          Pria  68.0  1.0  ...              270.0         0  285830.0
# 333466          Pria  45.0  1.0  ...               44.0         0  285831.0
#
# [333467 rows x 12 columns]

# %%
dataframe.describe()
# Out:
#                 Umur            SIM  ...       Tertarik             id
# count  319253.000000  319063.000000  ...  333467.000000  285831.000000
# mean       38.840008       0.997859  ...       0.122549  142916.000000
# std        15.526462       0.046218  ...       0.327919   82512.446734
# min        20.000000       0.000000  ...       0.000000       1.000000
# 25%        25.000000       1.000000  ...       0.000000   71458.500000
# 50%        36.000000       1.000000  ...       0.000000  142916.000000
# 75%        49.000000       1.000000  ...       0.000000  214373.500000
# max        85.000000       1.000000  ...       1.000000  285831.000000
#
# [8 rows x 9 columns]

# %% [markdown]
# ##PREPROCESSING

# %%
# Drop kolom id pada data train
dataframe.drop(dataframe.columns[11], axis=1, inplace=True)
dataframe
# Out:
#        Jenis_Kelamin  Umur  SIM  ...  Kanal_Penjualan  Lama_Berlangganan Tertarik
# 0             Wanita  49.0  1.0  ...             26.0              145.0        0
# 1               Pria  22.0  1.0  ...            152.0              241.0        0
# 2               Pria  24.0  1.0  ...            152.0               62.0        0
# 3               Pria  46.0  1.0  ...            124.0               34.0        0
# 4               Pria  35.0  1.0  ...            152.0              229.0        0
# ...              ...   ...  ...  ...              ...                ...      ...
# 333462        Wanita  23.0  1.0  ...            152.0              217.0        0
# 333463        Wanita  21.0  1.0  ...            152.0               50.0        0
# 333464        Wanita  23.0  1.0  ...            152.0              226.0        0
# 333465          Pria  68.0  1.0  ...            124.0              270.0        0
# 333466          Pria  45.0  1.0  ...             26.0               44.0        0
#
# [333467 rows x 11 columns]

# %%
# Membuang data yang missing value / NaN
dataframe.dropna(inplace=True)
dataframe
# Out:
#        Jenis_Kelamin  Umur  SIM  ...  Kanal_Penjualan  Lama_Berlangganan Tertarik
# 0             Wanita  49.0  1.0  ...             26.0              145.0        0
# 1               Pria  22.0  1.0  ...            152.0              241.0        0
# 2               Pria  24.0  1.0  ...            152.0               62.0        0
# 3               Pria  46.0  1.0  ...            124.0               34.0        0
# 4               Pria  35.0  1.0  ...            152.0              229.0        0
# ...              ...   ...  ...  ...              ...                ...      ...
# 333462        Wanita  23.0  1.0  ...            152.0              217.0        0
# 333463        Wanita  21.0  1.0  ...            152.0               50.0        0
# 333464        Wanita  23.0  1.0  ...            152.0              226.0        0
# 333465          Pria  68.0  1.0  ...            124.0              270.0        0
# 333466          Pria  45.0  1.0  ...             26.0               44.0        0
#
# [218704 rows x 11 columns]

# %%
dataframe.isnull().sum()
# Out:
# Jenis_Kelamin        0
# Umur                 0
# SIM                  0
# Kode_Daerah          0
# Sudah_Asuransi       0
# Umur_Kendaraan       0
# Kendaraan_Rusak      0
# Premi                0
# Kanal_Penjualan      0
# Lama_Berlangganan    0
# Tertarik             0
# dtype: int64

# %%
dataframe.isnull().any()
# Out:
# Jenis_Kelamin        False
# Umur                 False
# SIM                  False
# Kode_Daerah          False
# Sudah_Asuransi       False
# Umur_Kendaraan       False
# Kendaraan_Rusak      False
# Premi                False
# Kanal_Penjualan      False
# Lama_Berlangganan    False
# Tertarik             False
# dtype: bool

# %%
# Mengubah tipe data kategorikal menjadi numerikal
dataframe = dataframe.apply(lambda series: pd.Series(LabelEncoder().fit_transform(series[series.notnull()]),index=series[series.notnull()].index))
dataframe
# Out:
#         Jenis_Kelamin  Umur  SIM  ...  Kanal_Penjualan  Lama_Berlangganan  Tertarik
# 0                   1    29    1  ...               23                135         0
# 1                   0     2    1  ...              138                231         0
# 2                   0     4    1  ...              138                 52         0
# 3                   0    26    1  ...              115                 24         0
# 4                   0    15    1  ...              138                219         0
# ...               ...   ...  ...  ...              ...                ...       ...
# 333462              1     3    1  ...              138                207         0
# 333463              1     1    1  ...              138                 40         0
# 333464              1     3    1  ...              138                216         0
# 333465              0    48    1  ...              115                260         0
# 333466              0    25    1  ...               23                 34         0
#
# [218704 rows x 11 columns]

# %%
dataframe.dtypes
# Out:
# Jenis_Kelamin        int64
# Umur                 int64
# SIM                  int64
# Kode_Daerah          int64
# Sudah_Asuransi       int64
# Umur_Kendaraan       int64
# Kendaraan_Rusak      int64
# Premi                int64
# Kanal_Penjualan      int64
# Lama_Berlangganan    int64
# Tertarik             int64
# dtype: object

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 218704 entries, 0 to 333466
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Jenis_Kelamin      218704 non-null  int64
#  1   Umur               218704 non-null  int64
#  2   SIM                218704 non-null  int64
#  3   Kode_Daerah        218704 non-null  int64
#  4   Sudah_Asuransi     218704 non-null  int64
#  5   Umur_Kendaraan     218704 non-null  int64
#  6   Kendaraan_Rusak    218704 non-null  int64
#  7   Premi              218704 non-null  int64
#  8   Kanal_Penjualan    218704 non-null  int64
#  9   Lama_Berlangganan  218704 non-null  int64
#  10  Tertarik           218704 non-null  int64
# dtypes: int64(11)
# memory usage: 20.0 MB

# %% [markdown]
# ##Scalling

# %%
# Normalisasi dataframe dengan MinMax range [0,1]
new_dataframe = dataframe.copy()
new_dataframe = (dataframe - dataframe.min(axis=0)) / (dataframe.max(axis=0) - dataframe.min(axis=0))
new_dataframe
# Out:
#         Jenis_Kelamin      Umur  ...  Lama_Berlangganan  Tertarik
# 0                 1.0  0.446154  ...           0.467128       0.0
# 1                 0.0  0.030769  ...           0.799308       0.0
# 2                 0.0  0.061538  ...           0.179931       0.0
# 3                 0.0  0.400000  ...           0.083045       0.0
# 4                 0.0  0.230769  ...           0.757785       0.0
# ...               ...       ...  ...                ...       ...
# 333462            1.0  0.046154  ...           0.716263       0.0
# 333463            1.0  0.015385  ...           0.138408       0.0
# 333464            1.0  0.046154  ...           0.747405       0.0
# 333465            0.0  0.738462  ...           0.899654       0.0
# 333466            0.0  0.384615  ...           0.117647       0.0
#
# [218704 rows x 11 columns]

# %%
Plot_dataframe = new_dataframe.boxplot(figsize=(16,8))

# %%
# Split dataframe menjadi train dan test 80:20
df = new_dataframe
train_size = (int(len(df) * 0.80))
df = df.sample(frac=1, random_state=200).reset_index(drop=True)

#Data training
df_train = df[0:train_size]

#Data test
df_test = df[train_size:len(df)]

print("Jumlah data train: ", len(df_train))
print("Jumlah data test: ", len(df_test))
# Out:
# Jumlah data train:  174963
# Jumlah data test:  43741

# %%
df_train['Tertarik'].value_counts()
# Out:
# 0.0    153606
# 1.0     21357
# Name: Tertarik, dtype: int64

# %%
df_test['Tertarik'].value_counts()
# Out:
# 0.0    38440
# 1.0     5301
# Name: Tertarik, dtype: int64

# %% [markdown]
# # Data Preparation

# %%
# Data Train
x_train = df_train.drop(['Tertarik'], axis=1)
y_train = df_train['Tertarik'].values

# %%
x_train = x_train.values

# %%
#Data test

x_test = df_test.drop(['Tertarik'], axis=1)
y_test = df_test['Tertarik'].values

# %%
x_test = x_test.values

# %% [markdown]
# Membuat Histogram

# %%
df_train.hist(figsize = [15,10])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f695c2c8790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f695c292450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f695c247a50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f695c1f3b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f695c1c1690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f695c177c90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f695c139350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f695c0ee890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f695c0ee8d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f695c0ba210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f695c02f0d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f695bfe55d0>]],
#       dtype=object)

# %% [markdown]
# Drop kolom yang tidak digunakan

# %%
#kendaraan_test
dropKolom = ['SIM']
df_test = df_test.drop(dropKolom, axis = 1)

#kendaraan_train
dropKolom = ['SIM']
df_train = df_train.drop(dropKolom, axis = 1)

# %% [markdown]
# Membuat heatmap

# %%
plt.figure(figsize = (10,10))
sns.heatmap(df_train.corr(), annot = True)

# %% [markdown]
# #Classification dan evaluation

# %%
nb = GaussianNB()
nb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred_nb = nb.predict(x_test)

# %% [markdown]
# #Evaluation with Naive Bayes Method

# %%
def confusion_metrics (y_test,y_pred):
    # Untuk menentukan True Positive, False Positive, True Negative dan False Negative
    cm = metrics.confusion_matrix(y_test, y_pred)
    cm_df = pd.DataFrame(cm, 
                         columns = ['Predicted Negative', 'Predicted Positive'], 
                         index = ['Actual Negative', 'Actual Positive'])

    # Memasukkan nilai True Positive, False Positive, True Negative dan False Negative ke variable
    TN = cm_df.loc['Actual Negative','Predicted Negative']
    FN = cm_df.loc['Actual Positive','Predicted Negative']
    FP = cm_df.loc['Actual Negative','Predicted Positive']
    TP = cm_df.loc['Actual Positive','Predicted Positive']

    # Menampilkan jumlah masing-masing True Positive, False Positive, True Negative dan False Negative
    print('True Negative  : ',TN)
    print('False Negative : ',FN)
    print('False Positive : ',FP)
    print('True Positive  : ',TP)
    print('')

    # Menampilkan hasil perhitungan Precision, Recall dan F1-Score
    print(classification_report(y_test,y_pred))

# %%
confusion_metrics(y_test, y_pred_nb)
# Out:
# True Negative  :  22793
# False Negative :  136
# False Positive :  15647
# True Positive  :  5165
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.59      0.74     38440
#          1.0       0.25      0.97      0.40      5301
#
#     accuracy                           0.64     43741
#    macro avg       0.62      0.78      0.57     43741
# weighted avg       0.90      0.64      0.70     43741

# %%
data_test_nb = df_test.copy()
data_test_nb['Prediksi'] = y_pred_nb

# %%
data_test_nb
# Out:
#         Jenis_Kelamin      Umur  ...  Tertarik  Prediksi
# 174963            0.0  0.123077  ...       0.0       0.0
# 174964            0.0  0.692308  ...       0.0       0.0
# 174965            1.0  0.446154  ...       0.0       1.0
# 174966            1.0  0.153846  ...       0.0       0.0
# 174967            1.0  0.046154  ...       0.0       0.0
# ...               ...       ...  ...       ...       ...
# 218699            0.0  0.446154  ...       1.0       1.0
# 218700            0.0  0.076923  ...       0.0       0.0
# 218701            1.0  0.707692  ...       0.0       0.0
# 218702            0.0  0.707692  ...       0.0       1.0
# 218703            0.0  0.107692  ...       0.0       0.0
#
# [43741 rows x 11 columns]

# %% [markdown]
# #Classification with decision tree method

# %%
dtree =  tree.DecisionTreeClassifier(class_weight = 'balanced', min_samples_leaf = 15, random_state = 32)
dtree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', min_samples_leaf=15,
#                        random_state=32)

# %%
y_pred_dtree = dtree.predict(x_test)

# %% [markdown]
# #Evaluation with decision tree method

# %%
def confusion_metrics (y_test,y_pred):
    # Untuk menentukan True Positive, False Positive, True Negative dan False Negative
    cm = metrics.confusion_matrix(y_test, y_pred)
    cm_df = pd.DataFrame(cm, 
                         columns = ['Predicted Negative', 'Predicted Positive'], 
                         index = ['Actual Negative', 'Actual Positive'])

    # Memasukkan nilai True Positive, False Positive, True Negative dan False Negative ke variable
    TN = cm_df.loc['Actual Negative','Predicted Negative']
    FN = cm_df.loc['Actual Positive','Predicted Negative']
    FP = cm_df.loc['Actual Negative','Predicted Positive']
    TP = cm_df.loc['Actual Positive','Predicted Positive']

    # Menampilkan jumlah masing-masing True Positive, False Positive, True Negative dan False Negative
    print('True Negative  : ',TN)
    print('False Negative : ',FN)
    print('False Positive : ',FP)
    print('True Positive  : ',TP)
    print('')
    
    # Menampilkan hasil perhitungan Precision, Recall dan F1-Score
    print(classification_report(y_test,y_pred))

# %%
confusion_metrics(y_test, y_pred_dtree)
# Out:
# True Negative  :  28193
# False Negative :  1384
# False Positive :  10247
# True Positive  :  3917
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.73      0.83     38440
#          1.0       0.28      0.74      0.40      5301
#
#     accuracy                           0.73     43741
#    macro avg       0.61      0.74      0.62     43741
# weighted avg       0.87      0.73      0.78     43741

# %%
data_test_dtree = df_test.copy()
data_test_dtree['Prediksi'] = y_pred_dtree

# %%
data_test_dtree
# Out:
#         Jenis_Kelamin      Umur  ...  Tertarik  Prediksi
# 174963            0.0  0.123077  ...       0.0       0.0
# 174964            0.0  0.692308  ...       0.0       0.0
# 174965            1.0  0.446154  ...       0.0       1.0
# 174966            1.0  0.153846  ...       0.0       0.0
# 174967            1.0  0.046154  ...       0.0       0.0
# ...               ...       ...  ...       ...       ...
# 218699            0.0  0.446154  ...       1.0       1.0
# 218700            0.0  0.076923  ...       0.0       0.0
# 218701            1.0  0.707692  ...       0.0       0.0
# 218702            0.0  0.707692  ...       0.0       1.0
# 218703            0.0  0.107692  ...       0.0       0.0
#
# [43741 rows x 11 columns]
